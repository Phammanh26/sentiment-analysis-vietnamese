# %%
import wandb
api = wandb.Api()
run = api.run("phammanh26/sentiment-analyst-project")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/akb_env/lib/python3.8/site-packages/wandb/apis/normalize.py:24, in normalize_exceptions.<locals>.wrapper(*args, **kwargs)
#      <a href='file:///Users/phamvanmanh/opt/anaconda3/envs/akb_env/lib/python3.8/site-packages/wandb/apis/normalize.py?line=22'>23</a> try:
# ---> <a href='file:///Users/phamvanmanh/opt/anaconda3/envs/akb_env/lib/python3.8/site-packages/wandb/apis/normalize.py?line=23'>24</a>     return func(*args, **kwargs)
#      <a href='file:///Users/phamvanmanh/opt/anaconda3/envs/akb_env/lib/python3.8/site-packages/wandb/apis/normalize.py?line=24'>25</a> except requests.HTTPError as err:
#
# File ~/opt/anaconda3/envs/akb_env/lib/python3.8/site-packages/wandb/apis/public.py:712, in Api.run(self, path)
# ...
